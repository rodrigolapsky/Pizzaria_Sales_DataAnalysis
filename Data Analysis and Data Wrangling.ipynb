# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\Users\Rodrigo Lapsky\Documents\Dados\DataSets\Pizza\pizza_sales.csv')

# %%
print(df.shape)
df.head(15)
# Out:
# (48620, 12)
#     pizza_id  order_id   pizza_name_id  quantity order_date order_time  \
# 0        1.0       1.0      hawaiian_m       1.0   1/1/2015   11:38:36
# 1        2.0       2.0   classic_dlx_m       1.0   1/1/2015   11:57:40
# 2        3.0       2.0   five_cheese_l       1.0   1/1/2015   11:57:40
# 3        4.0       2.0     ital_supr_l       1.0   1/1/2015   11:57:40
# 4        5.0       2.0      mexicana_m       1.0   1/1/2015   11:57:40
# 5        6.0       2.0      thai_ckn_l       1.0   1/1/2015   11:57:40
# 6        7.0       3.0     ital_supr_m       1.0   1/1/2015   12:12:28
# 7        8.0       3.0    prsc_argla_l       1.0   1/1/2015   12:12:28
# 8        9.0       4.0     ital_supr_m       1.0   1/1/2015   12:16:31
# 9       10.0       5.0     ital_supr_m       1.0   1/1/2015   12:21:30
# 10      11.0       6.0       bbq_ckn_s       1.0   1/1/2015   12:29:36
# 11      12.0       6.0     the_greek_s       1.0   1/1/2015   12:29:36
# ...

# %%
print(df.duplicated().sum())
print(df.isnull().sum())
# Out:
# 0
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df = df.drop(columns=['pizza_id','pizza_name_id','order_id'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   quantity           48620 non-null  float64
#  1   order_date         48620 non-null  object
#  2   order_time         48620 non-null  object
#  3   unit_price         48620 non-null  float64
#  4   total_price        48620 non-null  float64
#  5   pizza_size         48620 non-null  object
#  6   pizza_category     48620 non-null  object
#  7   pizza_ingredients  48620 non-null  object
#  8   pizza_name         48620 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 3.3+ MB

# %%
for i in df.columns:
    print(f"column: {i}")
    print(df[i].unique())
    print("-" * 30)
# Out:
# column: quantity
# [1. 2. 3. 4.]
# ------------------------------
# column: order_date
# ['1/1/2015' '2/1/2015' '3/1/2015' '4/1/2015' '5/1/2015' '6/1/2015'
#  '7/1/2015' '8/1/2015' '9/1/2015' '10/1/2015' '11/1/2015' '12/1/2015'
#  '13-01-2015' '14-01-2015' '15-01-2015' '16-01-2015' '17-01-2015'
#  '18-01-2015' '19-01-2015' '20-01-2015' '21-01-2015' '22-01-2015'
#  '23-01-2015' '24-01-2015' '25-01-2015' '26-01-2015' '27-01-2015'
#  '28-01-2015' '29-01-2015' '30-01-2015' '31-01-2015' '1/2/2015' '2/2/2015'
#  '3/2/2015' '4/2/2015' '5/2/2015' '6/2/2015' '7/2/2015' '8/2/2015'
#  '9/2/2015' '10/2/2015' '11/2/2015' '12/2/2015' '13-02-2015' '14-02-2015'
#  '15-02-2015' '16-02-2015' '17-02-2015' '18-02-2015' '19-02-2015'
#  '20-02-2015' '21-02-2015' '22-02-2015' '23-02-2015' '24-02-2015'
#  '25-02-2015' '26-02-2015' '27-02-2015' '28-02-2015' '1/3/2015' '2/3/2015'
#  '3/3/2015' '4/3/2015' '5/3/2015' '6/3/2015' '7/3/2015' '8/3/2015'
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'], dayfirst=True, format='mixed')
df['month'] = df['order_date'].dt.month_name()

# %%
df['estimated_profit'] = df['total_price'] * 0.60

# %%
df.head()
# Out:
#    quantity order_date order_time  unit_price  total_price pizza_size  \
# 0       1.0 2015-01-01   11:38:36       13.25        13.25          M
# 1       1.0 2015-01-01   11:57:40       16.00        16.00          M
# 2       1.0 2015-01-01   11:57:40       18.50        18.50          L
# 3       1.0 2015-01-01   11:57:40       20.75        20.75          L
# 4       1.0 2015-01-01   11:57:40       16.00        16.00          M
#
#   pizza_category                                  pizza_ingredients  \
# 0        Classic           Sliced Ham, Pineapple, Mozzarella Cheese
# 1        Classic  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2         Veggie  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3        Supreme  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4         Veggie  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name    month  estimated_profit
# 0         The Hawaiian Pizza  January              7.95
# ...

# %%
df.to_csv('pizza.csv',index=False,sep=';',decimal=',',encoding='utf-8-sig')
